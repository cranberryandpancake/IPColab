# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena.jpg')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(gImg.shape)
cv2_imshow(gImg)
# Out:
# (512, 512, 3)
# <PIL.Image.Image image mode=L size=512x512>

# %%
def saturation(value):
  if(value > 255):
    value = 255
  elif (value <0):
    value = 0
  return value

# %%
kernel3 = np.ones((3,3),np.float32)/9
kernel5 = np.ones((5,5),np.float32)/25
kernel7 = np.ones((7,7),np.float32)/49

# %%
output = cv2.filter2D(gImg,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
output = cv2.filter2D(gImg,-1,kernel5)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
gOut = np.zeros((gImg.shape[0], gImg.shape[1]), dtype = np.ubyte)

# %%
for h in range(1, gImg.shape[0]-1):
  for w in range(1, gImg.shape[1]-1):
    sum = 0
    for i in range(-1,2):
      for j in range(-1,2):
        sum += gImg[h+i, w+j]*kernel3[i+1,j+1]
    sum = saturation(sum)
    gOut[h,w] = sum

cv2_imshow(gOut)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
output = cv2.filter2D(output,-1,kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
output = cv2.filter2D(output,-1,kernel5)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 8/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
output = cv2.filter2D(output,-1,kernel3)
output = output * 5
plt.imshow(output, cmap='gray')

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/fce(salt_pepper noise).bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(gImg.shape)
cv2_imshow(gImg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
outlmg = cv2.medianBlur(gImg,3)
plt.imshow(outlmg, cmap='gray')

# %%
outlmg = cv2.blur(gImg,(3,3))
plt.imshow(gImg, cmap='gray')

# %%
outlmg = cv2.medianBlur(gImg,3)
plt.imshow(outlmg, cmap='gray')

# %%
#img = cv2.imread('/content/drive/My Drive/ip/Images/fce(salt_pepper noise).bmp')
img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise2.jpg')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(gImg.shape)
cv2_imshow(gImg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1992962372.py in <cell line: 0>()
#       1 #img = cv2.imread('/content/drive/My Drive/ip/Images/fce(salt_pepper noise).bmp')
#       2 img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise2.jpg')
# ----> 3 print(img.shape)
#       4 gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       5 #print(gImg.shape)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
outlmg = cv2.blur(gImg1,(3,3))
cv2_imshow(outlmg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1319504920.py in <cell line: 0>()
# ----> 1 outlmg = cv2.blur(gImg1,(3,3))
#       2 cv2_imshow(outlmg)
#
# NameError: name 'gImg1' is not defined

# %%
#img = cv2.imread('/content/drive/My Drive/ip/Images/fce(salt_pepper noise).bmp')
#img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise2.jpg')
img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise1.jpg')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gImg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2439350873.py in <cell line: 0>()
#       2 #img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise2.jpg')
#       3 img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise1.jpg')
# ----> 4 print(img.shape)
#       5 gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       6 cv2_imshow(gImg)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
#img = cv2.imread('/content/drive/My Drive/ip/Images/fce(salt_pepper noise).bmp')
#img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise2.jpg')
img = cv2.imread('/content/drive/My Drive/ip/Images/Lena-Gaussian-noise1.jpg')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gImg)

# %%
outlmg = cv2.blur(gImg1,(3,3))
cv2_imshow(outlmg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1319504920.py in <cell line: 0>()
# ----> 1 outlmg = cv2.blur(gImg1,(3,3))
#       2 cv2_imshow(outlmg)
#
# NameError: name 'gImg1' is not defined
